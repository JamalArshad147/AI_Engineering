# %% [markdown]
# ```python
# # 📌 POLYNOMIAL FEATURES — Concise Notes
#
# # Why use PolynomialFeatures?
# # → Linear models can only fit straight lines.
# # → Real-world data is often curved.
# # → Solution: Create new features like x², x³, etc. so a *linear* model can fit *non-linear* patterns.
#
# # What does 'degree' mean?
# # → Highest power of the original feature(s) to include.
# # Example for a single input x = 3:
# #   degree=1 → [1, 3]
# #   degree=2 → [1, 3, 9]        # adds x²
# #   degree=3 → [1, 3, 9, 27]    # adds x³
# #   degree=4 → [1, 3, 9, 27, 81] # adds x⁴
#
# # How to choose degree?
# # • degree=1 → straight-line relationship
# # • degree=2 → U-shaped or parabolic curve (most common)
# # • degree=3 → S-shaped curve (one inflection point)
# # • degree≥4 → very wiggly curves (rare; high risk of overfitting)
#
# # ⚠️ Warning:
# # Higher degree ≠ better! Can cause overfitting (model memorizes noise).
# # Always validate on unseen data. Prefer simplest degree that works.
#
# https://data36.com/polynomial-regression-python-scikit-learn/
#
# # Below is the practical class code
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datasets/Position_Salaries.csv")

# %%
X = df[["Level"]].values
y = df["Salary"].values

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures

pr = PolynomialFeatures(degree=4)
X_poly = pr.fit_transform(X)
lr_2 = LinearRegression()
lr_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y)
plt.plot(X, lr.predict(X), color="r")
plt.title("Truth or Buff(Linear Regression)")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(X, y)
plt.plot(X, lr_2.predict(X_poly), color="r")
plt.title("Truth or Buff(Poly Regression)")
plt.xlabel("Position")
plt.ylabel("Salary")
plt.show()

# %%
lr.predict([[10]])
# Out:
# array([613454.54545455])

# %%
lr_2.predict(pr.fit_transform([[10]]))
# Out:
# array([988916.08391613])
