# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import spacy
import pandas as pd
import matplotlib.pyplot as plt
import re
from spacy import displacy

# %%
# LOAD DATA
bbc = pd.read_csv('./datasets/bbc_news.csv')
# bbc.head()

# %%
bbc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1000 non-null   int64
#  1   index        1000 non-null   int64
#  2   title        1000 non-null   object
#  3   pubDate      1000 non-null   object
#  4   guid         1000 non-null   object
#  5   link         1000 non-null   object
#  6   description  1000 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %%
title  = pd.DataFrame(bbc['title'])
title.head()
# Out:
#                                                title
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...

# %% [markdown]
# **Clean Data**

# %%
# lowercase
title['lower'] = title['title'].str.lower()
title.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                                lower
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...

# %%
# stopwords
en_stopwords = stopwords.words('english')
title['no_stopwords'] = title['lower'].apply(lambda x: " ".join([word for word in x.split() if word not in (en_stopwords)]))
title.head(3)
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
#
#                                                lower  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
#
#                                         no_stopwords
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community

# %%
# punctuation remove
title['no_stopwords_no_punctuations'] = title.apply(lambda x: re.sub(r"[^\w\s]", '', x['no_stopwords']), axis=1)
title.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                                lower  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                                         no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds
#
#                         no_stopwords_no_punctuations
# 0                                        refuse work
# 1  liz truss brief world reacts uk political turmoil
# 2     rationing energy nothing new offgrid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4         platinum jubilee 70 years queen 70 seconds

# %%
# tokenize

title['tokenize'] = title.apply(lambda x: word_tokenize(x['no_stopwords_no_punctuations']), axis=1) # why use axis?
# title.head()

# %%
# Lemmatization

lemmatizer = WordNetLemmatizer()
title['lemmatised'] = title['tokenize'].apply(lambda tokens: [lemmatizer.lemmatize(token) for token in tokens])
title.head()
# Out:
#                                                title  \
# 0                              Can I refuse to work?
# 1  'Liz Truss the Brief?' World reacts to UK poli...
# 2  Rationing energy is nothing new for off-grid c...
# 3  The hunt for superyachts of sanctioned Russian...
# 4  Platinum Jubilee: 70 years of the Queen in 70 ...
#
#                                                lower  \
# 0                              can i refuse to work?
# 1  'liz truss the brief?' world reacts to uk poli...
# 2  rationing energy is nothing new for off-grid c...
# 3  the hunt for superyachts of sanctioned russian...
# 4  platinum jubilee: 70 years of the queen in 70 ...
#
#                                         no_stopwords  \
# 0                                       refuse work?
# 1  'liz truss brief?' world reacts uk political t...
# 2    rationing energy nothing new off-grid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4        platinum jubilee: 70 years queen 70 seconds
#
#                         no_stopwords_no_punctuations  \
# 0                                        refuse work
# 1  liz truss brief world reacts uk political turmoil
# 2     rationing energy nothing new offgrid community
# 3      hunt superyachts sanctioned russian oligarchs
# 4         platinum jubilee 70 years queen 70 seconds
#
#                                             tokenize  \
# 0                                     [refuse, work]
# 1  [liz, truss, brief, world, reacts, uk, politic...
# 2  [rationing, energy, nothing, new, offgrid, com...
# 3  [hunt, superyachts, sanctioned, russian, oliga...
# 4  [platinum, jubilee, 70, years, queen, 70, seco...
#
#                                           lemmatised
# 0                                     [refuse, work]
# 1  [liz, truss, brief, world, reacts, uk, politic...
# 2  [rationing, energy, nothing, new, offgrid, com...
# 3  [hunt, superyachts, sanctioned, russian, oliga...
# 4   [platinum, jubilee, 70, year, queen, 70, second]

# %%
token_new_list = sum(title['tokenize'], []) # What?
token_clean_list = sum(title['lemmatised'], [])

# %%
nlp = spacy.load('en_core_web_sm')

# %%
spacy_doc = nlp(" ".join(token_new_list))

# %%
pos_df = pd.DataFrame(columns=['token', 'pos_tag'])
for token in spacy_doc:
    pos_df = pd.concat([pos_df, pd.DataFrame.from_records([{'token': token.text, 'pos_tag': token.pos_}])], ignore_index=True)

# %%
pos_df_counts = pos_df.groupby(['token', 'pos_tag']).size().reset_index(name='counts').sort_values(by='counts', ascending=False)
pos_df_counts.head(10)
# Out:
#         token pos_tag  counts
# 31       2022     NUM      47
# 1237  england   PROPN      40
# 935       cup   PROPN      36
# 3946       uk   PROPN      33
# 2544      new     ADJ      32
# 4096      war    NOUN      32
# 3262     says    VERB      30
# 3951  ukraine    VERB      28
# 4210    world    NOUN      28
# 4211    world   PROPN      26

# %%
nouns = pos_df_counts[pos_df_counts['pos_tag']=='NOUN'][0:10]
nouns
# Out:
#        token pos_tag  counts
# 4096     war    NOUN      32
# 4210   world    NOUN      28
# 2275     man    NOUN      23
# 2707  papers    NOUN      18
# 3049  record    NOUN      17
# 1233  energy    NOUN      17
# 2845  police    NOUN      16
# 971      day    NOUN      15
# 4128    week    NOUN      15
# 934      cup    NOUN      14

# %%
verb = pos_df_counts[pos_df_counts['pos_tag']=='VERB'][0:10]
verb
# Out:
#         token pos_tag  counts
# 3262     says    VERB      30
# 3951  ukraine    VERB      28
# 1471    found    VERB      13
# 4174      win    VERB      10
# 1562      get    VERB       9
# 2271     make    VERB       8
# 4184     wins    VERB       8
# 1763     hits    VERB       8
# 3691     take    VERB       8
# 3261      say    VERB       8

# %%
# NER
ner_df = pd.DataFrame(columns=['token', 'ner_tag'])

for token in spacy_doc.ents:
    if pd.isna(token.label_) is False:
        ner_df = pd.concat([ner_df, pd.DataFrame.from_records([{'token': token.text, 'ner_tag': token.label_}])], ignore_index=True)
        # ner_df.head(15)

# %%
# Import these at the top of your notebook
from IPython.display import HTML, display

# ... your other code to create spacy_doc ...

# Tell displacy not to auto-render, and just return the HTML
html = displacy.render(spacy_doc, style='ent', jupyter=False)

# Now, manually display the HTML string
display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">refuse work liz truss brief world reacts uk political turmoil rationing energy nothing new offgrid community hunt superyachts sanctioned
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  oligarchs platinum jubilee
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     70 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  queen
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     70 seconds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  red
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bull
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  found guilty breaking formula
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  budget cap world triathlon championship series flora duffy beats
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     georgia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  taylorbrown womens title
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     terry hall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  coventry scooter rideout pays tribute singer post office fujitsu face inquiry horizon scandal pavement parking frightens me uk interest rates rise affect high could go stayed storm happens now
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  nations scotlands best since
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     99
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  beat best ireland ever long liz truss survive prime minister platinum
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jubilee beacons
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  light across globe celebrate queens reign top student loan interest rate cut
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  england
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  said theyd take baby medics story
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     week pictures 1117 june 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  xi jinping
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hong kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  tight security city marks
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  handover rescues carried silence listen sounds life
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nick pope
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     newcastle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  goalkeeper extends incredible clean sheet record
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  plans become next big space power barcelona thrash leaders real
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     madrid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  famous
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     clasico
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  win
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kuenssberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  budget can not mask big changes economy nicola bulley search know disappearance cost living christmas lights displays survive energy crisis
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100yearold
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  edinburgh man still working
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three d
