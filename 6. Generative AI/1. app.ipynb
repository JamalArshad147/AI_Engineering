# %%
from dotenv import load_dotenv

load_dotenv()

# %%
from openai import OpenAI

client = OpenAI()

response = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages = [
        {
            'role': 'user',
            'content': 'Explain GenAI in one sentence'
        }
    ]
)

# %%
print(response)

# %%
print(response.choices[0].message.content)

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", 
    contents="Explain GenAI in one sentence"
)

# %%
print(response.text)

# %%
# from openai import OpenAI

# client = OpenAI(
#     api_key='Gemini api key here',
#     base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
# )

# response = client.chat.completions.create(
#     model="gemini-2.5-flash",
#     messages=[
#         {
#             "role": "user",
#             "content": "Explain GenAI in one sentence"
#         }
#     ]
# )

# %%
print(response.choices[0].message.content)

# %%
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
# Out:
# True

# %%
from openai import OpenAI
client  = OpenAI()

response = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages = [
        {'role': 'developer', 'content': "You are a very creative poet"},
        {'role': 'user', 'content': "Write 4 lines on cofee, laptop, coding, moon"},
    ],
        temperature = 1,
)

print(response.choices[0].message.content)

# %%
for model in client.models.list():
    print(model.id)

# %%
# Streaming API responses

from openai import OpenAI
client  = OpenAI()

response = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages = [
        {'role': 'developer', 'content': "You are a very creative poet"},
        {'role': 'user', 'content': "Write 20 lines on cofee, laptop, coding, moon"},
    ],
        temperature = 1,
        stream = True
)

# print(response.choices[0].message.content)

for chunk in response:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")

# %%
# Using local Base64 images as input

from IPython.display import Image, display
# image_path = 'imgs/triangle.jpg'
image_path = 'imgs/triangle2.jpg'
display(Image(image_path))

# %%
import base64
def encode_image(image_path):
    with open(image_path, 'rb') as image_file:
        image_binary_data = image_file.read()
        return base64.b64encode(image_binary_data)

# %%
base64_image = encode_image(image_path).decode("utf-8")
system_message = "You are a math tutor"
# prompt = "What is the perimeter of this triangle"
prompt = "Explain this image"

from openai import OpenAI
client  = OpenAI()

response = client.chat.completions.create(
    model = 'gpt-4o-mini',
    messages = [
        {'role': 'system', 'content': system_message},
        {'role': 'user', 'content': [
            {'type': 'text', 'text': prompt},
            {'type': 'image_url', 'image_url': {
                'url': f'data:image/jpg;base64,{base64_image}'
            }}
        ]},
    ],
    temperature=1
)

# %%
print(response.choices[0].message.content)
# Out:
# The image depicts a triangle labeled as triangle ABC. Here are some key features of the triangle:
#
# 1. **Vertices and Sides**:
#    - The vertices are labeled A, B, and C.
#    - Side AC is 12 units long (labeled next to point C).
#    - Side AB is 15 units long (labeled next to point B).
#    - Side BC is 8 units long (although not labeled on the side itself, it's inferred from the graphical layout).
#
# 2. **Triangle Description**:
#    - The text "This is a triangle" indicates that the focus is on highlighting the shape.
#
# 3. **Basic Properties**:
#    - The triangle is formed by connecting the three vertices.
#    - The lengths of the sides suggest that this is a scalene triangle since all sides have different lengths.
#
# Overall, the image serves as a simple visual representation of a triangle and its components. If you have specific questions about the triangle, such as calculating its area or checking if it satisfies the triangle inequality, feel free to ask!
