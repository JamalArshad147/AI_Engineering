# %%
print('I am', 25, "years old.")
# Out:
# I am 25 years old.

# %%
x = "Orange", "Banana", "Cherry"
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = 10 
y = 20

y, x = x, y

print(x, y)
# Out:
# 20 10

# %%
print (5, "hi")
# not print(5 + "hi")
# Out:
# 5 hi

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %%
x = 10
if(x == 10):
    x=11

print(x)
# Out:
# 11

# %%
x = memoryview(bytes(5))
x

# %%
import random as rd

rd.randrange(1,10)
# Out:
# 3

# %%
class Person:
    def __init__(self, name, age):
        self.age = age
        self.name = name
    
p1 = Person('Linus', 28)

print(p1.name)
print(p1.age)
# Out:
# Linus
# 28
